# %% [markdown]
# ![alt text](DataKind_orange.png)

# %% [markdown]
# # Omidyar Extractives Project 1
# ## Clean Contract Text (Notebook 4 of 8)
# ### 1. Reads in contract text
# ### 2. Strips HTML from text
# ### 3. Cleans text for NLP prep (remove unicode, special characters, stopwords, etc.)
# ### 4. Outputs cleaned text appended to dataframe from Notebook 1

# %%
import re
import string
import pandas as pd
from HTMLParser import HTMLParser
import nltk
from nltk.corpus import stopwords
from langdetect import detect

import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %%
contracts = pd.read_pickle('contract_data/1_contracts_with_text.pkl')
outfile = 'contract_data/2_contracts_with_text.pkl'

# %%
print "Number of contracts: " + str(len(contracts))
# Out:
# Number of contracts: 1496

# %% [markdown]
# ### Parse by paragraph, strip HTML, carriage returns, newline characters

# %%
def get_paragraphs(text):
    return re.split('\s{4,}',text)

# %%
class MLStripper(HTMLParser):
    def __init__(self):
        self.reset()
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ''.join(self.fed)

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

# %%
contracts['Text_by_Paragraph'] = contracts['Contract_Text'].apply(get_paragraphs)

# %%
pd.set_option('max_colwidth',200)
contracts[contracts['Text_by_Paragraph'].map(len) ==2]
# Out:
#                         OCID Category  \
# 215   ocds-591adf-7104921871       rc
# 283   ocds-591adf-8080364797       rc
# 303   ocds-591adf-4212712774       rc
# 342   ocds-591adf-1623268944       rc
# 469   ocds-591adf-3068184322       rc
# 488   ocds-591adf-5374338853       rc
# 515   ocds-591adf-3538681265       rc
# 520   ocds-591adf-3156014237       rc
# 583   ocds-591adf-2742639589       rc
# 652   ocds-591adf-6064437287       rc
# 752   ocds-591adf-5608935364       rc
# 778   ocds-591adf-1557880338       rc
# 864   ocds-591adf-3541607034       rc
# 936   ocds-591adf-4815087699       rc
# 946   ocds-591adf-2949159236       rc
# 1041  ocds-591adf-4013712466       rc
# 1129  ocds-591adf-3691607772       rc
#
#                                                                                                                                                                                                 Contract Name  \
# 215                                                                                                                                       Kosmos Energy Offshore Morocco HC, Cap Boujdour Offshore, PSA, 2011
# 283                                                                                                                                Minera Yanacocha S.R.L., Maqui Maqui, Investment Promotion Agreement, 1994
# 303                                                                                                              Compa��a Minera Oro Candente S.A., Exploration License, Investment Promotion Agreement, 2003
# 342                                                                                                                                      Eramen Minerals, Incorporated - Annex of MPSA No. 209-2005-III, 2005
# 469                                                                                                             Empresa Mo�ambicana de Explora��o Mineira, Minas Moatize, Limitada, Moatize, Concession, 2013
# 488                                                                                                                                            La Societe Agip Mineraria, Concession El borma - Tunisia, 1960
# 515                                                                                                                                          Philex Mining Corporation - Annex of MPSA No. 276-2009-CAR, 2009
# 520                                                                                                             Shuley Mine, Incorporated - Annex of MPSA No. 072-97-XIII (Surigao Mineral Reservation), 1997
# 583                 Ivanhoe Energy Ecuador Inc., Empresa Estatal de Petr�leos del Ecuador, Empresa Estatal de Exploraci�n y Producci�n de Petr�leos del Ecuador, Block 20 Pungarayacu, Service Contract, 2008
# 652                                                                                                                                       Aral Petroleum Capital CJSC, North Block, Exploration License, 2002
# 752                                                                                                          Hyperdynamics / SCS Corporation, Blocks B4, partial C3, C4, D3, E3, F2, F3, Amendment, PSA, 2010
# 778                                                                                                                                                       DRC, G�camines, CMD [KMT] - Kingamyambo - JVA, 2004
# 864                                                                                                                                      Kenmare Morna Mining Ltd., Moma, Congolone, Quinga, Concession, 2002
# 936                                                                                                                                                      Kosmos Energy Suriname, Block 42 Offshore, PSA, 2011
# 946                                                                                                                                                           Congo Iron S.A., Mont Nabemba, Concession, 2016
# 1041                                                                                                     CTP Construction and Mining Corporation - MPSA No. 158-2000-XIII (Surigao Mineral Reservation), 2000
# 1129  Kosmos Energy Deepwater Morocco, Pathfinder Hydrocarbons Ventures Limited, Foum Assaka Offshore I, Foum Assaka Offshore II, Foum Assaka Offshore III, Foum Assaka Offshore IV (collectively "Foum As...
#
#                                            Contract Identifier Language  \
# 215                                                        NaN       en
# 283                                                        NaN       es
# 303                                                        NaN       es
# 342                                 ph_Sta-Cruz-Nickel-Project       en
# 469       mz_dd20130413_Moatize-No-1163C_Concession_Emem_Minas       pt
# 488                                                        NaN       fr
# 515                            ph_Padcal-Copper-Gold-Operation       en
# 520                                    ph_Nonoc-Nickel-Project       en
# 583                                                        NaN       en
# 652   kz_North-Block_dd20021229_Exploration-Contract_Aral-CJSC       en
# 752                                                        NaN       en
# 778                cd_Kingamyambo_dd20040323_JVA_G�camines_CMD       fr
# 864        mz_dd20020121_Moma_Congolone_Quinga_Concession_KMML       pt
# 936                                                        NaN       en
# 946                                                        NaN       fr
# 1041                                 ph_Dahican-Nickel-Project       en
# 1129                                                       NaN       en
#
#                                Country Name                Resource  \
# 215                                 Morocco            Hydrocarbons
# 283                                    Peru                    Gold
# 303                                    Peru          other minerals
# 342                             Philippines                  Nickel
# 469                              Mozambique                    Coal
# 488                                 Tunisia            Hydrocarbons
# 515                             Philippines             Copper;Gold
# 520                             Philippines                  Nickel
# 583                                 Ecuador            Hydrocarbons
# 652                              Kazakhstan            Hydrocarbons
# 752                                  Guinea            Hydrocarbons
# 778   Congo, the Democratic Republic of the           Cobalt;Copper
# 864                              Mozambique  Ilmenite;Rutile;Zircon
# 936                                Suriname            Hydrocarbons
# 946                                   Congo            Hydrocarbons
# 1041                            Philippines         Chromite;Nickel
# 1129                                Morocco            Hydrocarbons
#
#                                                   Contract Type  \
# 215                      Production or Profit Sharing Agreement
# 283                              Investment Promotion Agreement
# 303   Exploration Permit/License;Investment Promotion Agreement
# 342                      Production or Profit Sharing Agreement
# 469                                        Concession Agreement
# 488                                        Concession Agreement
# 515                      Production or Profit Sharing Agreement
# 520                      Production or Profit Sharing Agreement
# 583                                            Service Contract
# 652                                  Exploration Permit/License
# 752   Contract Amendment;Production or Profit Sharing Agreement
# 778                                     Joint Venture Agreement
# 864                                        Concession Agreement
# 936                      Production or Profit Sharing Agreement
# 946                                        Concession Agreement
# 1041                     Production or Profit Sharing Agreement
# 1129                                       Concession Agreement
#
#      Signature Date    Document Type  \
# 215      2011-07-11         Contract
# 283      1994-05-20         Contract
# 303      2003-09-15         Contract
# 342      2005-04-19  Contract Annexe
# 469      2013-04-03         Contract
# 488      1960-06-10         Contract
# 515      2009-01-19  Contract Annexe
# 520      1997-08-07  Contract Annexe
# 583      2008-10-08         Contract
# 652      2002-12-29         Contract
# 752      2010-03-25         Contract
# 778      2004-03-23         Contract
# 864      2002-01-21         Contract
# 936             NaN         Contract
# 946      2016-05-20         Contract
# 1041     2000-05-02         Contract
# 1129     2011-05-04         Contract
#
#                                                                                                        ...                                                                                                     \
# 215                                                                                                    ...
# 283                                                                                                    ...
# 303                                                                                                    ...
# 342                                                                                                    ...
# 469                                                                                                    ...
# 488                                                                                                    ...
# 515                                                                                                    ...
# 520                                                                                                    ...
# 583                                                                                                    ...
# 652                                                                                                    ...
# 752                                                                                                    ...
# 778                                                                                                    ...
# 864                                                                                                    ...
# 936                                                                                                    ...
# 946                                                                                                    ...
# 1041                                                                                                   ...
# 1129                                                                                                   ...
#
#      Disclosure Mode Retrieval Date  \
# 215          Company     2016-08-09
# 283       Government     2016-02-13
# 303       Government     2016-01-20
# 342       Government            NaN
# 469       Government     2016-01-02
# 488       Government     2016-07-16
# 515       Government            NaN
# 520       Government            NaN
# 583              NaN            NaN
# 652            Other     2015-08-31
# 752          Company     2016-08-02
# 778            Other     2015-11-06
# 864       Government     2016-01-02
# 936          Company     2016-07-17
# 946       Government     2016-10-05
# 1041      Government            NaN
# 1129         Company            NaN
#
#                                                                                                                                                            Pdf Url  \
# 215                       https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/2148/2148-kosmos-energy-offshore-morocco-hc-cap-boujdour-offshore-psa-2011.pdf
# 283                             https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1684/1684-peru-minera-yanacocha-exploration-investment-contract-1994.pdf
# 303                          https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1609/1609-peru-compania-minera-oro-exploration-investment-contract-2003.pdf
# 342                                                           https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1098/1098-annexes-mpsa-no-209-2005-iii.pdf
# 469                                      https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1498/1498-mozambique-emem-minas-tm-no-1163c-concession-2013.pdf
# 488                             https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/2046/2046-la-societe-agip-mineraria-concession-el-borma-tunisia-1960.pdf
# 515                                                           https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1088/1088-annexes-mpsa-no-276-2009-car.pdf
# 520                                                            https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1103/1103-annexes-mpsa-no-072-97-xiii.pdf
# 583                                                        https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/779/779-empresa-petroecuador-ecuador-2007.pdf
# 652                             https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1060/1060-kazakhstan-aral-petroleum-north-block-exploration-contract.pdf
# 752   https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/2142/2142-hyperdynamics-scs-corporation-blocks-b4-partial-c3-c4-d3-e3-f2-f3-amendment-psa-2010.pdf
# 778                                                         https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1383/1383-drc-gecamines-cmd-kmt-jva-2004.pdf
# 864                                  https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1497/1497-mozambique-kmml-moma-congolone-quinga-concession-2002.pdf
# 936                                                            https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/1844/1844-kosmos-energy-suriname-2011.pdf
# 946                                             https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/2353/2353-congo-iron-sa-mont-nabemba-concession-2016.pdf
# 1041                                                                   https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/87/87-mpsa-no-158-00-xiii-smr.pdf
# 1129                                                    https://resourcecontracts-nrgi.s3-us-west-2.amazonaws.com/841/841-kosmos-phvl-morocco-2011-foum-assaka.pdf
#
#      Deal Number  \
# 215          NaN
# 283          NaN
# 303          NaN
# 342          NaN
# 469          NaN
# 488          NaN
# 515          NaN
# 520          NaN
# 583          NaN
# 652          NaN
# 752          NaN
# 778          NaN
# 864          NaN
# 936          NaN
# 946          NaN
# 1041         NaN
# 1129         NaN
#
#                                                                                                                             Contract Note  \
# 215                                                                                                                                   NaN
# 283                                                                                                                                   NaN
# 303                                                                                                                                   NaN
# 342                                                                                                                                   NaN
# 469                                                                                                                                   NaN
# 488                                                                                                                                   NaN
# 515                                                                                                                                   NaN
# 520                                                                                                                                   NaN
# 583                                                                                                                                   NaN
# 652                                                                                                                                   NaN
# 752                                                                                                                                   NaN
# 778   This document refers to Kingamyambo Musonoi Tailings (KMT) which is the name of the Joint Venture company created for this project.
# 864                                                                                                                                   NaN
# 936                                                                                                                                   NaN
# 946                                                                                                                                   NaN
# 1041                                                                                                                                  NaN
# 1129                                                                                                                                  NaN
#
#      Matrix Page Annotation Category Annotation Text  \
# 215          NaN                 NaN             NaN
# 283          NaN                 NaN             NaN
# 303          NaN                 NaN             NaN
# 342          NaN                 NaN             NaN
# 469          NaN                 NaN             NaN
# 488          NaN                 NaN             NaN
# 515          NaN                 NaN             NaN
# 520          NaN                 NaN             NaN
# 583          NaN                 NaN             NaN
# 652          NaN                 NaN             NaN
# 752          NaN                 NaN             NaN
# 778          NaN                 NaN             NaN
# 864          NaN                 NaN             NaN
# 936          NaN                 NaN             NaN
# 946          NaN                 NaN             NaN
# 1041         NaN                 NaN             NaN
# 1129         NaN                 NaN             NaN
#
#                                                                                                                                                                                                 Contract_Text  \
# 215   EX-10.27 28 a13-19720_1ex10d27.htm EX-10.27<br /><br />\nExhibit 10.27<br /><br />\nPETROLEUM AGREEMENT<br /><br />\n<br /><br />\nREGARDING<br /><br />\n<br /><br />\nTHE EXPLORATION FOR AND EXPL...
# 283   CONTRATO DE GARANTIAS Y MEDIDAS DE PROMOCION A LA INVERSION<br /><br />\r\n<br /><br />\r\nDECRETO SUPREMO N° 0 4-94-EM<br /><br />\r\n<br /><br />\r\nSeñor Notario:<br /><br />\r\n<br /><br />\r\...
# 303   ,<br /><br />\nMINISTERIO<br /><br />\nDEENERGIA<br /><br />\ny MINAS<br /><br />\nDPDM-DGM<br /><br />\n<br /><br />\nFOLIO:<br /><br />\n<br /><br />\n211<br /><br />\nNómeros<br /><br />\n<br /...
# 342   ︶<br /><br />\n <br /><br />\n <br /><br />\n一<br /><br />\n<br /><br />\nANNEX― A<br /><br />\n<br /><br />\nSECRETARY'S<br /><br />\nCER丁 lFiCATE<br /><br />\n<br /><br />\nν<br /><br />\n<br />...
# 469   [image]<br /><br />\r\nREPÚBLICA DE MOÇAMBIQUE MINISTÉRIO DOS RECURSOS MINERAIS<br /><br />\r\n<br /><br />\r\nCONTRATO MINEIRO ENTRE<br /><br />\r\n<br /><br />\r\nO ESTADO REPRESENTADO PELO MINI...
# 488   CONVENTION<br /><br />\r\n<br /><br />\r\nentre<br /><br />\r\n<br /><br />\r\nL’Etat Tunisien et la Société Agip Mineraria<br /><br />\r\n<br /><br />\r\n<br /><br />\r\nEDITION JANVIER 1982<br /...
# 515   ANNEX“ A"<br /><br />\nV<br /><br />\n<br /><br />\nCORPORATE SECRETARY'S<br /><br />\nCERttIFiCAT10N<br /><br />\n1<br /><br />\n<br /><br />\n▼<br /><br />\n<br /><br />\n/<br /><br />\n<br /><...
# 520   Annex B<br /><br />\n<br /><br />\nPNNTX<br /><br />\n<br /><br />\nG<br /><br />\n<br /><br />\nOrry,tor..<br /><br />\n<br /><br />\nO<br /><br />\n<br /><br />\nNonoc lsland<br /><br />\n<br />...
# 583   ENGLISH TRANSLATION OF CONTRACT AS SIGNED<br /><br />\nOCTOBER 8, 2008<br /><br />\nSPECIFIC SERVICES CONTRACT FOR DEVELOMENT, PRODUCTION AND<br /><br />\nUPGRADING OF CRUDE OIL<br /><br />\nIN B...
# 652   UNOFFICIAL TRANSLATION<br /><br />\nPREPARED BY DENTON WILDE SAPTE<br /><br />\nANNEX A<br /><br />\n<br /><br />\n(The State Emblem of the Republic of Kazakhstan)<br /><br />\n<br /><br />\nCONTR...
# 752   EX-10.1 2 v179282_ex10-1.htm<br /><br />\n<br /><br />\nAMENDMENT N° 1<br /><br />\nTO THE HYDROCARBONS PRODUCTION SHARING CONTRACT<br /><br />\nBETWEEN THE REPUBLIC OF GUINEA AND SCS CORPORATION<...
# 778   rL<br /><br />\n<br /><br />\n-<br /><br />\n<br /><br />\nCONTRAT D'ASSOCIATION PORTANT SUR UN PROJET<br /><br />\nD'INDUSTRIE MlNlERE<br /><br />\n<br /><br />\nREJETS DE KINGAMYAMBO, VALLEE DE ...
# 864   [image]<br /><br />\r\n<br /><br />\r\nREPÚBLICA DE MOÇAMBIQUE MINISTÉRIO DOS RECURSOS MINERAIS E ENERGIA<br /><br />\r\nCONTRATO<br /><br />\r\n<br /><br />\r\nDE<br /><br />\r\n<br /><br />\r\nP...
# 936   t<br /><br />\nTable of Contents<br /><br />\n<br /><br />\nUNITED STATES<br /><br />\nSECURITIES AND EXCHANGE COMMISSION<br /><br />\nWashington, D.C. 20549<br /><br />\n<br /><br />\nFORM 10-Q<b...
# 946   58e ANNEE - EDITION SPECIALE N° 5<br /><br />\nDu 20 mai 2016<br /><br />\n<br /><br />\nHors texte<br /><br />\nPrix : 2000 F CFA<br /><br />\n<br /><br />\nRÉPUBLIQUE DU CONGO<br /><br />\nUnité...
# 1041  <div>Revised Integrated MPSA for Mineral Reservation</div><div><br></div><div>MINERAL PRODUCTION SHARING AGREEMENT </div><div>MPSA 158-2000-XII-SMR</div><div><br></div><div>This MINERAL PRODUCTION...
# 1129  Table of Contents<br /><br />\n<br /><br />\nUNITED STATES<br /><br />\nSECURITIES AND EXCHANGE COMMISSION<br /><br />\nWashington, D.C. 20549<br /><br />\n<br /><br />\nFORM 10-Q<br /><br />\n(Ma...
#
#                                                                                                                                                                                             Text_by_Paragraph
# 215   [EX-10.27 28 a13-19720_1ex10d27.htm EX-10.27<br /><br />\nExhibit 10.27<br /><br />\nPETROLEUM AGREEMENT<br /><br />\n<br /><br />\nREGARDING<br /><br />\n<br /><br />\nTHE EXPLORATION FOR AND EXP...
# 283   [CONTRATO DE GARANTIAS Y MEDIDAS DE PROMOCION A LA INVERSION<br /><br />\r\n<br /><br />\r\nDECRETO SUPREMO N° 0 4-94-EM<br /><br />\r\n<br /><br />\r\nSeñor Notario:<br /><br />\r\n<br /><br />\r...
# 303   [,<br /><br />\nMINISTERIO<br /><br />\nDEENERGIA<br /><br />\ny MINAS<br /><br />\nDPDM-DGM<br /><br />\n<br /><br />\nFOLIO:<br /><br />\n<br /><br />\n211<br /><br />\nNómeros<br /><br />\n<br ...
# 342   [︶<br /><br />\n <br /><br />\n <br /><br />\n一<br /><br />\n<br /><br />\nANNEX― A<br /><br />\n<br /><br />\nSECRETARY'S<br /><br />\nCER丁 lFiCATE<br /><br />\n<br /><br />\nν<br /><br />\n<br /...
# 469   [[image]<br /><br />\r\nREPÚBLICA DE MOÇAMBIQUE MINISTÉRIO DOS RECURSOS MINERAIS<br /><br />\r\n<br /><br />\r\nCONTRATO MINEIRO ENTRE<br /><br />\r\n<br /><br />\r\nO ESTADO REPRESENTADO PELO MIN...
# 488   [CONVENTION<br /><br />\r\n<br /><br />\r\nentre<br /><br />\r\n<br /><br />\r\nL’Etat Tunisien et la Société Agip Mineraria<br /><br />\r\n<br /><br />\r\n<br /><br />\r\nEDITION JANVIER 1982<br ...
# 515   [ANNEX“ A"<br /><br />\nV<br /><br />\n<br /><br />\nCORPORATE SECRETARY'S<br /><br />\nCERttIFiCAT10N<br /><br />\n1<br /><br />\n<br /><br />\n▼<br /><br />\n<br /><br />\n/<br /><br />\n<br />...
# 520   [Annex B<br /><br />\n<br /><br />\nPNNTX<br /><br />\n<br /><br />\nG<br /><br />\n<br /><br />\nOrry,tor..<br /><br />\n<br /><br />\nO<br /><br />\n<br /><br />\nNonoc lsland<br /><br />\n<br /...
# 583   [ENGLISH TRANSLATION OF CONTRACT AS SIGNED<br /><br />\nOCTOBER 8, 2008<br /><br />\nSPECIFIC SERVICES CONTRACT FOR DEVELOMENT, PRODUCTION AND<br /><br />\nUPGRADING OF CRUDE OIL<br /><br />\nIN ...
# 652   [UNOFFICIAL TRANSLATION<br /><br />\nPREPARED BY DENTON WILDE SAPTE<br /><br />\nANNEX A<br /><br />\n<br /><br />\n(The State Emblem of the Republic of Kazakhstan)<br /><br />\n<br /><br />\nCONT...
# 752   [EX-10.1 2 v179282_ex10-1.htm<br /><br />\n<br /><br />\nAMENDMENT N° 1<br /><br />\nTO THE HYDROCARBONS PRODUCTION SHARING CONTRACT<br /><br />\nBETWEEN THE REPUBLIC OF GUINEA AND SCS CORPORATION...
# 778   [rL<br /><br />\n<br /><br />\n-<br /><br />\n<br /><br />\nCONTRAT D'ASSOCIATION PORTANT SUR UN PROJET<br /><br />\nD'INDUSTRIE MlNlERE<br /><br />\n<br /><br />\nREJETS DE KINGAMYAMBO, VALLEE DE...
# 864   [[image]<br /><br />\r\n<br /><br />\r\nREPÚBLICA DE MOÇAMBIQUE MINISTÉRIO DOS RECURSOS MINERAIS E ENERGIA<br /><br />\r\nCONTRATO<br /><br />\r\n<br /><br />\r\nDE<br /><br />\r\n<br /><br />\r\n...
# 936   [t<br /><br />\nTable of Contents<br /><br />\n<br /><br />\nUNITED STATES<br /><br />\nSECURITIES AND EXCHANGE COMMISSION<br /><br />\nWashington, D.C. 20549<br /><br />\n<br /><br />\nFORM 10-Q<...
# 946   [58e ANNEE - EDITION SPECIALE N° 5<br /><br />\nDu 20 mai 2016<br /><br />\n<br /><br />\nHors texte<br /><br />\nPrix : 2000 F CFA<br /><br />\n<br /><br />\nRÉPUBLIQUE DU CONGO<br /><br />\nUnit...
# 1041  [<div>Revised Integrated MPSA for Mineral Reservation</div><div><br></div><div>MINERAL PRODUCTION SHARING AGREEMENT </div><div>MPSA 158-2000-XII-SMR</div><div><br></div><div>This MINERAL PRODUCTIO...
# 1129  [Table of Contents<br /><br />\n<br /><br />\nUNITED STATES<br /><br />\nSECURITIES AND EXCHANGE COMMISSION<br /><br />\nWashington, D.C. 20549<br /><br />\n<br /><br />\nFORM 10-Q<br /><br />\n(M...
#
# [17 rows x 37 columns]

# %%
contracts['Text_by_Paragraph'][0]
# Out:
# ['INVESTMENT AGREEMENT<br /><br />\n<br /><br />\nBETWEEN<br /><br />\nTHE GOVERNMENT OF MONGOLIA<br /><br />\nAND<br /><br />\nIVANHOE MINES MONGOLIA INC LLC<br /><br />\nAND<br /><br />\nIVANHOE MINES LTD<br /><br />\nAND<br /><br />\nRIO TINTO INTERNATIONAL HOLDINGS LIMITED<br /><br />\n<br /><br />\n\x0cINVESTMENT AGREEMENT<br /><br />\n<br /><br />\nIn accordance with Article 29 of the Minerals Law of Mongolia (hereinafter referred to as the<br /><br />\n\xe2\x80\x9cMinerals Law\xe2\x80\x9d), Resolution Number 40 dated 4 December 2008 and Resolution Number 57<br /><br />\ndated 16 July 2009 respectively of the State Great Khural and Government Resolution Number<br /><br />\n308 dated 6 October 2009:<br /><br />\nThe Minister of Finance, the Minister of Mineral Resources and Energy and the Minister<br /><br />\nof Nature, Environment and Tourism, together representing and upon authorization of the<br /><br />\nGovernment of Mongolia;<br /><br />\nand<br /><br />\nIvanhoe Mines Mongolia Inc LLC (hereinafter referred to as the \xe2\x80\x9cInvestor\xe2\x80\x9d);<br /><br />\nand<br /><br />\nIvanhoe Mines Ltd (hereinafter referred to as \xe2\x80\x9cIvanhoe Mines Ltd\xe2\x80\x9d);<br /><br />\nand<br /><br />\nRio Tinto International Holdings Limited (hereinafter referred to as \xe2\x80\x9cRio Tinto\xe2\x80\x9d);<br /><br />\nhave entered into this Agreement on this 6th day of October 2009;<br /><br />\nHaving regard to the following:<br /><br />\nThe Investor having invested a significant amount of capital in the OT Project through<br /><br />\nthe financial capability of Ivanhoe Mines Ltd and Rio Tinto;<br /><br />\nArticle 4.1.12 of the Minerals Law and Resolution Number 27 of the State Great Khural<br /><br />\ndated 6 February 2007;<br /><br />\nThe Private Placement Agreement dated 18 October 2006 between Ivanhoe Mines Ltd<br /><br />\nand Rio Tinto (as amended);<br /><br />\nThe purpose of this Agreement being to define and regulate a relationship in regard to<br /><br />\nmaintaining for a certain period a stable Tax and operational environment, the sale of<br /><br />\nProducts at international market prices by the Investor, the guarantee of the Investor\xe2\x80\x99s<br /><br />\nright to use and spend its income at its own discretion, the amount and term of the<br /><br />\ninvestment, the undertaking of mining activities with minimum damage to the<br /><br />\nenvironment and human health, the rehabilitation of the environment, not to have a<br /><br />\nnegative effect on other industries and operations, the social and economic development<br /><br />\nof the Southern Gobi region and creation of new jobs, the creation of business<br /><br />\nopportunities for Mongolian companies and individuals, compensation for damages to<br /><br />\nproperty, basis for the termination of this Agreement, and rights and obligations of the<br /><br />\n<br /><br />\nPage 1<br /><br />\n<br /><br />\n\x0cParties during the period of exploring, mining and processing operations within the<br /><br />\nContract Area;<br /><br />\nResolution Number 57 of the State Great Khural dated 16 July 2009 has resolved to authorise the<br /><br />\nGovernment to enter into this Agreement and upon such entry, the rights and obligations under<br /><br />\nthis Agreement shall be binding on the Parties with the agreement being as follows:<br /><br />\n<br /><br />\n1.<br /><br />\n<br /><br />\nCHAPTER ONE: GENERAL<br /><br />\n<br /><br />\n1.1.<br /><br />\n<br /><br />\nExcept as provided by Clause 15.26, this Agreement shall come into effect on and from<br /><br />\nthe Effective Date and remain in effect, in accordance with Article 29.3 of the Minerals<br /><br />\nLaw, for an initial period of 30 (thirty) years.<br /><br />\n<br /><br />\n1.2.<br /><br />\n<br /><br />\nThe Investor shall have a right to apply for and obtain from competent authorities in<br /><br />\naccordance with relevant laws and regulations of Mongolia all leases, license ...

# %%
contracts['HTML_Stripped_Text'] = contracts['Contract_Text'].apply(strip_tags)

# %%
characters_to_replace = ['\xef','\xbb','\xbf','\r','\n']
for char in characters_to_replace:
    contracts['HTML_Stripped_Text'] = contracts['HTML_Stripped_Text'].str.replace(char," ")

# %%
contracts['TextLength'] = contracts['HTML_Stripped_Text'].str.len()

# %%
## Remove short documents
contracts = contracts[contracts['TextLength'] > 2000].copy()

# %% [markdown]
# ### Clean Text

# %%
unicode_re = nltk.regexp.re.compile(u'('u'\ud83c[\udf00-\udfff]|'
                        u'\ud83d[\udc00-\ude4f\ude80-\udeff]|'
                        u'[\u2600-\u26FF\u2700-\u27BF])+',
                        nltk.regexp.re.UNICODE)
url_re = r'(?:www|https?\://)\S+'

# %%
def unicode_remove(text):
    try:
        return text.decode('unicode_escape').encode('ascii','ignore')
    except:
        try:
            return text.decode('string-escape').encode('ascii','ignore')
        except:
            return repr(text).translate(None,r'\\x')

def perform_lowercase(text):
    """
    Mutates and returns text where all characters are lowercased
    """
    new_text = text.lower()
    return new_text

def urlpath_replace(text):
    """
    Replaces URL with URL base path
    """
    new_text = text
    urls = nltk.regexp.re.findall(url_re,text)
    for url in urls:
        try:
            parsed = urlparse.urlparse(url)
            urlnetloc = parsed.netloc
            urlpath = parsed.path
            if urlnetloc != '':
                new_text = text.replace(url,urlnetloc)
            else:
                new_text = text.replace(url,urlpath)
            text = new_text
        except:
            pass
    return new_text

def emoji_replace_word(text):
    """
    Replaces emoji byte representations with ' EMOJI ' 
    Uses UCS-4 wide code points for the regex
    http://stackoverflow.com/questions/26568722/remove-unicode-emoji-using-re-in-python
    """
    if isinstance(text, unicode):
        new_text = nltk.regexp.re.sub(unicode_re, ' emoji ', text)
        return new_text
    else:
        return text

def remove_underscore(text):
    new_text = text.replace('_',' ')
    return new_text

def punctuation_remove(text):
    """
    Mutates and returns text where all punctuation are replaced
    """
    chars = re.escape(string.punctuation)
    return re.sub(r'['+chars+']', ' ',text)

def doublespace_remove(text):
    return re.sub(' +',' ',text)

# %%
def cleaning(text):
    function_list = [
        unicode_remove, perform_lowercase, urlpath_replace, 
        emoji_replace_word, punctuation_remove, 
        remove_underscore, doublespace_remove
                ]
    for func in function_list:
        text = func(text)
    
    return text

# %%
contracts['CleanText'] = contracts.apply(lambda row: row['HTML_Stripped_Text'] if row['Language'] == 'ar' else cleaning(row['HTML_Stripped_Text']),axis=1)

# %% [markdown]
# ### Optimizing for NLP

# %%
stopwords = set(stopwords.words('english'))
stopwords.update(stopword_list)
def remove_stopwords(text):
    return ' '.join([i for i in text.lower().split() if i not in stopwords])
